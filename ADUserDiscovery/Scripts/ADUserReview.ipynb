# %%
{
    "cells": [
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "# ADUserReview.ipynb\n",
                "**Purpose**: Review group & GPO memberships from ADUserDiscovery export and tag decisions (Keep / Remove / CAB Review / Unsure)\n",
                "\n",
                "No external dependencies. Everything runs locally."
            ]
        },
        {
            "cell_type": "code",
            "execution_count": null,
            "metadata": {},
            "outputs": [],
            "source": [
                "# Load AD Discovery JSON\n",
                "import json\n",
                "import pandas as pd\n",
                "from pathlib import Path\n",
                "\n",
                "# Update with the actual path to your export\n",
                "json_path = Path('../exports/USERNAME/ad_user_summary_YYYYMMDD_HHmmss.json')\n",
                "with open(json_path, 'r', encoding='utf-8') as f:\n",
                "    ad_data = json.load(f)"
            ]
        },
        {
            "cell_type": "code",
            "execution_count": null,
            "metadata": {},
            "outputs": [],
            "source": [
                "# Extract groups and GPOs into DataFrames\n",
                "groups = ad_data.get(\"Groups\", [])\n",
                "gpos = ad_data.get(\"GPOs\", [])\n",
                "\n",
                "df_groups = pd.DataFrame(groups, columns=[\"GroupName\"])\n",
                "df_groups[\"Decision\"] = \"\"\n",
                "\n",
                "df_gpos = pd.DataFrame(gpos, columns=[\"GPOName\"])\n",
                "df_gpos[\"Decision\"] = \"\""
            ]
        },
        {
            "cell_type": "code",
            "execution_count": null,
            "metadata": {},
            "outputs": [],
            "source": [
                "# Preview Group Decisions Table\n",
                "df_groups.style.set_properties(**{'text-align': 'left'})"
            ]
        },
        {
            "cell_type": "code",
            "execution_count": null,
            "metadata": {},
            "outputs": [],
            "source": [
                "# Preview GPO Decisions Table\n",
                "df_gpos.style.set_properties(**{'text-align': 'left'})"
            ]
        },
        {
            "cell_type": "code",
            "execution_count": null,
            "metadata": {},
            "outputs": [],
            "source": [
                "# Optional – add a tagging helper to set decision by rule (e.g. default to 'CAB Review' if name contains 'Admin')\n",
                "df_groups.loc[df_groups['GroupName'].str.contains(\"admin\", case=False, na=False), 'Decision'] = \"CAB Review\"\n",
                "df_gpos.loc[df_gpos['GPOName'].str.contains(\"usb\", case=False, na=False), 'Decision'] = \"Keep\""
            ]
        },
        {
            "cell_type": "code",
            "execution_count": null,
            "metadata": {},
            "outputs": [],
            "source": [
                "# Export results to CSV for audit or CAB presentation\n",
                "df_groups.to_csv(\"decision_groups.csv\", index=False)\n",
                "df_gpos.to_csv(\"decision_gpos.csv\", index=False)"
            ]
        },
        {
            "cell_type": "code",
            "execution_count": null,
            "metadata": {},
            "outputs": [],
            "source": [
                "# Export Markdown Summary\n",
                "lines = [\"# AD Review Summary\\n\"]\n",
                "lines.append(\"## Group Membership Decisions\\n\")\n",
                "for _, row in df_groups.iterrows():\n",
                "    lines.append(f\"- **{row['GroupName']}**: {row['Decision']}\")\n",
                "\n",
                "lines.append(\"\\n## GPO Linkage Decisions\\n\")\n",
                "for _, row in df_gpos.iterrows():\n",
                "    lines.append(f\"- **{row['GPOName']}**: {row['Decision']}\")\n",
                "\n",
                "with open(\"decision_summary.md\", \"w\", encoding='utf-8') as f:\n",
                "    f.write(\"\\n\".join(lines))"
            ]
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "**You can now open `decision_summary.md` or `decision_groups.csv` in VSCode, GitHub, or submit to CAB.**"
            ]
        }
    ],
    "metadata": {
        "kernelspec": {
            "display_name": "Python 3",
            "language": "python",
            "name": "python3"
        },
        "language_info": {
            "name": "python",
            "version": "3.11"
        }
    },
    "nbformat": 4,
    "nbformat_minor": 5
}
